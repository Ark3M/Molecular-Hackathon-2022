# %%
import copy
import gc
import random
import re
from typing import List, Tuple, Union
import uuid

import numpy as np
from sklearn.base import BaseEstimator, RegressorMixin
from sklearn.decomposition import PCA
from sklearn.feature_selection import VarianceThreshold
from sklearn.model_selection import StratifiedKFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import KBinsDiscretizer
from sklearn.utils import check_X_y, check_array
from sklearn.utils.validation import check_is_fitted
import tensorflow as tf
import tensorflow_addons as tfa


def build_preprocessor(X: np.ndarray, seed: int) -> Pipeline:
    preprocessor = Pipeline(steps=[
        (
            'selector',
            VarianceThreshold()
        ),
        (
            'standard_scaler',
            StandardScaler(with_mean=True, with_std=True)
        ),
        (
            'pca',
            PCA(random_state=seed)
        )
    ])
    preprocessor.fit(X.astype(np.float64))
    return preprocessor


def build_neural_network(input_size: int, layer_size: int, n_classes: int,
                         n_layers: int, dropout_rate: float, scale_coeff: float,
                         nn_name: str) -> tf.keras.Model:
    feature_vector = tf.keras.layers.Input(
        shape=(input_size,), dtype=tf.float32,
        name=f'{nn_name}_feature_vector'
    )
    hidden_layer = tf.keras.layers.AlphaDropout(
        rate=dropout_rate,
        seed=random.randint(0, 2147483647),
        name=f'{nn_name}_dropout1'
    )(feature_vector)
    for layer_idx in range(1, (2 * n_layers) // 3 + 1):
        try:
            kernel_initializer = tf.keras.initializers.LecunNormal(
                seed=random.randint(0, 2147483647)
            )
        except:
            kernel_initializer = tf.compat.v1.keras.initializers.lecun_normal(
                seed=random.randint(0, 2147483647)
            )
        hidden_layer = tf.keras.layers.Dense(
            units=layer_size,
            activation='selu',
            kernel_initializer=kernel_initializer,
            bias_initializer='zeros',
            name=f'{nn_name}_dense{layer_idx}'
        )(hidden_layer)
        hidden_layer = tf.keras.layers.AlphaDropout(
            rate=dropout_rate,
            seed=random.randint(0, 2147483647),
            name=f'{nn_name}_dropout{layer_idx + 1}'
        )(hidden_layer)
    try:
        kernel_initializer = tf.keras.initializers.LecunNormal(
            seed=random.randint(0, 2147483647)
        )
    except:
        kernel_initializer = tf.compat.v1.keras.initializers.lecun_normal(
            seed=random.randint(0, 2147483647)
        )
    cls_layer = tf.keras.layers.Dense(
        units=n_classes,
        activation=None,
        use_bias=True,
        kernel_initializer=kernel_initializer,
        name=f'{nn_name}_classification'
    )(hidden_layer)
    for layer_idx in range((2 * n_layers) // 3 + 1, n_layers + 1):
        try:
            kernel_initializer = tf.keras.initializers.LecunNormal(
                seed=random.randint(0, 2147483647)
            )
        except:
            kernel_initializer = tf.compat.v1.keras.initializers.lecun_normal(
                seed=random.randint(0, 2147483647)
            )
        hidden_layer = tf.keras.layers.Dense(
            units=layer_size,
            activation='selu',
            kernel_initializer=kernel_initializer,
            bias_initializer='zeros',
            name=f'{nn_name}_dense{layer_idx}'
        )(hidden_layer)
        hidden_layer = tf.keras.layers.AlphaDropout(
            rate=dropout_rate,
            seed=random.randint(0, 2147483647),
            name=f'{nn_name}_dropout{layer_idx + 1}'
        )(hidden_layer)
    try:
        kernel_initializer = tf.keras.initializers.LecunNormal(
            seed=random.randint(0, 2147483647)
        )
    except:
        kernel_initializer = tf.compat.v1.keras.initializers.lecun_normal(
            seed=random.randint(0, 2147483647)
        )
    output_layer = tf.keras.layers.Dense(
        units=1,
        activation=None,
        use_bias=True,
        kernel_initializer=kernel_initializer,
        name=f'{nn_name}_regression'
    )(hidden_layer)
    neural_network = tf.keras.Model(
        inputs=feature_vector,
        outputs=[output_layer, cls_layer],
        name=nn_name
    )
    radam = tfa.optimizers.RectifiedAdam(learning_rate=1e-3)
    ranger = tfa.optimizers.Lookahead(radam, sync_period=6, slow_step_size=0.5)
    losses = {
        f'{nn_name}_regression': tf.keras.losses.MeanAbsoluteError(),
        f'{nn_name}_classification': tf.keras.losses.CategoricalCrossentropy(
            label_smoothing=0.01,
            from_logits=True
        )
    }
    loss_weights = {
        f'{nn_name}_regression': 1.0,
        f'{nn_name}_classification': 0.5
    }
    metrics = {
        f'{nn_name}_regression': [
            tf.keras.metrics.MeanAbsoluteError()
        ]
    }
    neural_network.compile(
        optimizer=ranger,
        loss=losses,
        loss_weights=loss_weights,
        metrics=metrics
    )
    return neural_network


def predict_by_ensemble(input_data: np.ndarray,
                        ensemble: List[tf.keras.Model],
                        postprocessing: StandardScaler,
                        minibatch: int) -> np.ndarray:
    num_samples = input_data.shape[0]
    ensemble_size = len(ensemble)
    predictions_of_ensemble = np.empty((ensemble_size, num_samples),
                                       dtype=np.float64)
    for model_idx, cur_model in enumerate(ensemble):
        y_mean = cur_model.predict(input_data, batch_size=minibatch)[0]
        predictions_of_ensemble[model_idx, :] = y_mean.flatten()
    y = np.mean(predictions_of_ensemble, axis=0)
    y = postprocessing.inverse_transform(y.reshape((y.shape[0], 1))).flatten()
    return y


def discretize_targets(targets: np.ndarray) -> np.ndarray:
    set_of_target_values = set()
    for cur in targets:
        set_of_target_values.add(int(round(100.0 * cur)))
    n_classes = max(3, len(set_of_target_values) // 20)
    discretized = KBinsDiscretizer(
        n_bins=n_classes,
        encode='ordinal',
        strategy='kmeans'
    ).fit_transform(
        targets.reshape((targets.shape[0], 1))
    ).reshape((targets.shape[0],)).astype(np.int32)
    discretized = discretized.astype(np.int32)
    return discretized


class SNNRegressor(BaseEstimator, RegressorMixin):
    def __init__(self, ensemble_size: int = 20,
                 hidden_layer_size: int = 256, n_layers: int = 18,
                 dropout_rate: float = 3e-4,
                 max_epochs: int = 1000, patience: int = 15,
                 minibatch_size: int = 4096, validation_fraction: float = 0.1,
                 verbose: bool = False, clear_session: bool = True,
                 random_seed: Union[int, None] = None):
        super(SNNRegressor, self).__init__()
        self.ensemble_size = ensemble_size
        self.hidden_layer_size = hidden_layer_size
        self.n_layers = n_layers
        self.dropout_rate = dropout_rate
        self.max_epochs = max_epochs
        self.patience = patience
        self.minibatch_size = minibatch_size
        self.verbose = verbose
        self.validation_fraction = validation_fraction
        self.clear_session = clear_session
        self.random_seed = random_seed

    def fit(self, X, y, **kwargs):
        self.check_params(
            ensemble_size=self.ensemble_size,
            hidden_layer_size=self.hidden_layer_size,
            n_layers=self.n_layers,
            minibatch_size=self.minibatch_size,
            dropout_rate=self.dropout_rate,
            max_epochs=self.max_epochs,
            patience=self.patience,
            validation_fraction=self.validation_fraction,
            verbose=self.verbose,
            clear_session=self.clear_session
        )
        X_, y_ = check_X_y(X, y,
                           force_all_finite='allow-nan',
                           ensure_min_samples=max(self.ensemble_size * 3, 100),
                           multi_output=False, y_numeric=True,
                           estimator='SNNRegressor')
        if 'feature_names' in kwargs:
            feature_names = kwargs['feature_names']
            if (not isinstance(feature_names, list)) and \
                    (not isinstance(feature_names, tuple)):
                err_msg = f'`{feature_names}` is wrong! ' \
                          f'Expected `{type([1, 2])}`, ' \
                          f'got `{type(kwargs["feature_names"])}`.'
                raise ValueError(err_msg)
        else:
            max_number_width = len(str(X_.shape[1]))
            feature_names = ['x{0:>0{1}}'.format(col_idx, max_number_width)
                             for col_idx in range(X_.shape[1])]
        if hasattr(self, 'deep_ensemble_'):
            del self.deep_ensemble_
        if hasattr(self, 'names_of_deep_ensemble_'):
            del self.names_of_deep_ensemble_
        if hasattr(self, 'preprocessor_'):
            del self.preprocessor_
        if hasattr(self, 'postprocessor_'):
            del self.postprocessor_
        if hasattr(self, 'random_gen_'):
            del self.random_gen_
        gc.collect()
        if self.clear_session:
            tf.keras.backend.clear_session()
        self.random_gen_ = np.random.default_rng(
            seed=(self.random_seed if hasattr(self, 'random_seed') else None)
        )
        self.preprocessor_ = build_preprocessor(
            X_, seed=self.random_gen_.integers(0, 2147483647)
        )
        if self.verbose:
            print('')
        self.postprocessor_ = StandardScaler(with_mean=True, with_std=True)
        self.postprocessor_.fit(y_.reshape((y_.shape[0], 1)))
        X_ = self.preprocessor_.transform(
            X_.astype(np.float64)
        ).astype(np.float32)
        y_ = self.postprocessor_.transform(
            y_.reshape((y_.shape[0], 1))
        ).reshape((y_.shape[0],))
        all_indices = np.array(list(range(X_.shape[0])), dtype=np.int32)
        self.random_gen_.shuffle(all_indices)
        X_ = X_[all_indices]
        y_ = y_[all_indices]
        del all_indices
        gc.collect()
        y_class_ = discretize_targets(y_)
        self.n_classes_ = int(np.max(y_class_) + 1)
        y_class__ = np.zeros((y_class_.shape[0], self.n_classes_),
                             dtype=np.float32)
        for sample_idx, class_idx in enumerate(y_class_):
            y_class__[sample_idx, class_idx] = 1.0
        if self.verbose:
            class_freq = np.zeros((self.n_classes_,), dtype=np.int32)
            for class_idx in y_class_:
                class_freq[class_idx] += 1
            max_num_width = max(map(lambda it: len(str(it)), class_freq))
            for class_idx, freq in enumerate(class_freq):
                print('Class {0:>02}: {1:>{2}} samples'.format(class_idx, freq,
                                                               max_num_width))
            print('')
        splitting = []
        for _ in range(self.ensemble_size):
            instant_splitting = list(StratifiedKFold(
                n_splits=int(round(1.0 / self.validation_fraction)),
                shuffle=True,
                random_state=self.random_gen_.integers(0, 2147483647)
            ).split(X_, y_class_))
            splitting.append(instant_splitting[0])
            del instant_splitting
        self.feature_vector_size_ = X_.shape[1]
        self.deep_ensemble_ = []
        self.names_of_deep_ensemble_ = []
        for alg_id in range(self.ensemble_size):
            model_uuid = str(uuid.uuid1()).split('-')[0]
            model_name = f'snn_regressor_{alg_id + 1}_{model_uuid}'
            regression_output_name = f'{model_name}_regression'
            self.names_of_deep_ensemble_.append(model_name)
            train_index, test_index = splitting[alg_id]
            steps_per_epoch = len(train_index) // self.minibatch_size
            train_dataset = tf.data.Dataset.from_tensor_slices(
                (
                    X_[train_index],
                    (
                        y_[train_index].flatten(),
                        y_class__[train_index]
                    )
                )
            ).repeat().shuffle(len(train_index)).batch(self.minibatch_size)
            val_dataset = tf.data.Dataset.from_tensor_slices(
                (
                    X_[test_index],
                    (
                        y_[test_index].flatten(),
                        y_class__[test_index]
                    )
                )
            ).batch(self.minibatch_size)
            new_model = build_neural_network(
                input_size=self.feature_vector_size_,
                layer_size=self.hidden_layer_size,
                n_classes=self.n_classes_,
                n_layers=self.n_layers,
                dropout_rate=self.dropout_rate,
                scale_coeff=self.postprocessor_.scale_[0],
                nn_name=model_name
            )
            if self.verbose:
                print('====================')
                print(f'NEURAL NETWORK {alg_id + 1}')
                print('====================')
                print('')
                new_model.summary()
                print('')
            callbacks = [
                tf.keras.callbacks.EarlyStopping(
                    monitor=f'val_{regression_output_name}_mean_absolute_error',
                    restore_best_weights=True, mode='min',
                    patience=self.patience, verbose=self.verbose
                )
            ]
            new_model.fit(
                train_dataset, epochs=self.max_epochs,
                steps_per_epoch=steps_per_epoch,
                callbacks=callbacks, validation_data=val_dataset,
                verbose=(2 if self.verbose else 0)
            )
            del callbacks, train_dataset, val_dataset, train_index, test_index
            self.deep_ensemble_.append(new_model)
            del new_model
            gc.collect()
        return self

    def predict(self, X):
        check_is_fitted(self, ['deep_ensemble_', 'names_of_deep_ensemble_',
                               'preprocessor_', 'postprocessor_',
                               'random_gen_', 'feature_vector_size_',
                               'n_classes_'])
        X_ = check_array(X, force_all_finite='allow-nan',
                         estimator='SNNRegressor')
        X_ = self.preprocessor_.transform(
            X_.astype(np.float64)
        ).astype(np.float32)
        y = predict_by_ensemble(
            input_data=X_,
            postprocessing=self.postprocessor_,
            ensemble=self.deep_ensemble_,
            minibatch=self.minibatch_size
        )
        return y

    def fit_predict(self, X, y, **kwargs):
        return self.fit(X, y).predict(X)

    def get_params(self, deep=True) -> dict:
        return {
            'ensemble_size': self.ensemble_size,
            'hidden_layer_size': self.hidden_layer_size,
            'n_layers': self.n_layers,
            'dropout_rate': self.dropout_rate,
            'max_epochs': self.max_epochs,
            'patience': self.patience,
            'minibatch_size': self.minibatch_size,
            'verbose': self.verbose,
            'validation_fraction': self.validation_fraction,
            'clear_session': self.clear_session,
            'random_seed': (self.random_seed if hasattr(self, 'random_seed')
                            else None)
        }

    def set_params(self, **params):
        for parameter, value in params.items():
            self.__setattr__(parameter, value)
        return self

    def _copy_deep_ensemble(self) -> List[tf.keras.Model]:
        new_deep_ensemble = []
        re_for_hidden_layer = re.compile(r'_dense\d+$')
        for alg_id in range(self.ensemble_size):
            model_uuid = str(uuid.uuid1()).split('-')[0]
            model_name = f'snn_regressor_{alg_id + 1}_{model_uuid}'
            new_model = build_neural_network(
                input_size=self.feature_vector_size_,
                layer_size=self.hidden_layer_size,
                n_classes=self.n_classes_,
                n_layers=self.n_layers,
                dropout_rate=self.dropout_rate,
                scale_coeff=self.postprocessor_.scale_[0],
                nn_name=model_name
            )
            new_model.build(input_shape=(None, self.feature_vector_size_))
            old_model = self.deep_ensemble_[alg_id]
            n_copied = 0
            for old_layer, new_layer in zip(old_model.layers, new_model.layers):
                if old_layer.name.endswith('_classification'):
                    copy_weight = True
                elif old_layer.name.endswith('_regression'):
                    copy_weight = True
                else:
                    if re_for_hidden_layer.search(old_layer.name) is None:
                        copy_weight = False
                    else:
                        copy_weight = True
                if copy_weight:
                    n_copied += 1
                    new_layer.set_weights(old_layer.get_weights())
            if n_copied < 1:
                err_msg = f'The neural network {alg_id + 1} cannot be copied!'
                raise ValueError(err_msg)
            new_deep_ensemble.append(new_model)
        return new_deep_ensemble

    def __copy__(self):
        cls = self.__class__
        result = cls.__new__(cls)
        result.set_params(
            ensemble_size=self.ensemble_size,
            hidden_layer_size=self.hidden_layer_size,
            n_layers=self.n_layers,
            dropout_rate=self.dropout_rate,
            max_epochs=self.max_epochs,
            patience=self.patience,
            minibatch_size=self.minibatch_size,
            verbose=self.verbose,
            validation_fraction=self.validation_fraction,
            clear_session=self.clear_session,
            random_seed=self.random_seed
        )
        try:
            check_is_fitted(self, ['deep_ensemble_', 'names_of_deep_ensemble_',
                                   'preprocessor_', 'postprocessor_',
                                   'random_gen_', 'feature_vector_size_',
                                   'n_classes_'])
            is_fitted = True
        except:
            is_fitted = False
        if is_fitted:
            result.deep_ensemble_ = self.deep_ensemble_
            result.names_of_deep_ensemble_ = self.names_of_deep_ensemble_
            result.preprocessor_ = self.preprocessor_
            result.postprocessor_ = self.postprocessor_
            result.random_gen_ = self.random_gen_
            result.feature_vector_size_ = self.feature_vector_size_
            result.n_classes_ = self.n_classes_
        return result

    def __deepcopy__(self, memodict={}):
        cls = self.__class__
        result = cls.__new__(cls)
        memodict[id(self)] = result
        result.set_params(
            ensemble_size=self.ensemble_size,
            hidden_layer_size=self.hidden_layer_size,
            n_layers=self.n_layers,
            dropout_rate=self.dropout_rate,
            max_epochs=self.max_epochs,
            patience=self.patience,
            minibatch_size=self.minibatch_size,
            verbose=self.verbose,
            validation_fraction=self.validation_fraction,
            clear_session=self.clear_session,
            random_seed=self.random_seed
        )
        try:
            check_is_fitted(self, ['deep_ensemble_', 'names_of_deep_ensemble_',
                                   'preprocessor_', 'postprocessor_',
                                   'random_gen_', 'feature_vector_size_',
                                   'n_classes_'])
            is_fitted = True
        except:
            is_fitted = False
        if is_fitted:
            result.feature_vector_size_ = self.feature_vector_size_
            result.n_classes_ = self.n_classes_
            result.names_of_deep_ensemble_ = copy.deepcopy(
                self.names_of_deep_ensemble_,
                memo=memodict
            )
            result.preprocessor_ = copy.deepcopy(self.preprocessor_,
                                                 memo=memodict)
            result.postprocessor_ = copy.deepcopy(self.postprocessor_,
                                                  memo=memodict)
            if self.random_gen_ is None:
                result.random_gen_ = None
            else:
                result.random_gen_ = copy.deepcopy(self.random_gen_,
                                                   memo=memodict)
            result.deep_ensemble_ = self._copy_deep_ensemble()
        return result

    def __getstate__(self):
        params = self.get_params(True)
        try:
            check_is_fitted(self, ['deep_ensemble_', 'names_of_deep_ensemble_',
                                   'preprocessor_', 'postprocessor_',
                                   'random_gen_', 'feature_vector_size_',
                                   'n_classes_'])
            is_fitted = True
        except:
            is_fitted = False
        if is_fitted:
            params['names_of_deep_ensemble_'] = copy.deepcopy(
                self.names_of_deep_ensemble_
            )
            params['feature_vector_size_'] = self.feature_vector_size_
            params['n_classes_'] = self.n_classes_
            params['preprocessor_'] = copy.deepcopy(self.preprocessor_)
            params['postprocessor_'] = copy.deepcopy(self.postprocessor_)
            if self.random_gen_ is None:
                params['random_gen_'] = None
            else:
                params['random_gen_'] = copy.deepcopy(self.random_gen_)
            params['deep_ensemble_'] = []
            for alg_id in range(self.ensemble_size):
                params['deep_ensemble_'].append(
                    self.deep_ensemble_[alg_id].get_weights()
                )
        return params

    def __setstate__(self, state: dict):
        if not isinstance(state, dict):
            err_msg = f'The `state` is wrong! Expected `{type({"a": 1})}`, ' \
                      f'got `{type(state)}`.'
            raise ValueError(err_msg)
        self.check_params(**state)
        is_fitted = ('deep_ensemble_' in state)
        if is_fitted:
            if 'names_of_deep_ensemble_' not in state:
                err_msg = 'The `names_of_deep_ensemble_` is not found ' \
                          'in the `state`!'
                raise ValueError(err_msg)
            if 'feature_vector_size_' not in state:
                err_msg = 'The `feature_vector_size_` is not found ' \
                          'in the `state`!'
                raise ValueError(err_msg)
            if 'preprocessor_' not in state:
                err_msg = 'The `preprocessor_` is not found in the `state`!'
                raise ValueError(err_msg)
            if 'postprocessor_' not in state:
                err_msg = 'The `postprocessor_` is not found in the `state`!'
                raise ValueError(err_msg)
        self.set_params(**state)
        if hasattr(self, 'deep_ensemble_'):
            del self.deep_ensemble_
        if hasattr(self, 'names_of_deep_ensemble_'):
            del self.names_of_deep_ensemble_
        if hasattr(self, 'preprocessor_'):
            del self.preprocessor_
        if hasattr(self, 'postprocessor_'):
            del self.postprocessor_
        if hasattr(self, 'random_gen_'):
            del self.random_gen_
        gc.collect()
        if self.clear_session:
            tf.keras.backend.clear_session()
        if is_fitted:
            self.feature_vector_size_ = state['feature_vector_size_']
            self.n_classes_ = state['n_classes_']
            self.names_of_deep_ensemble_ = copy.deepcopy(
                state['names_of_deep_ensemble_']
            )
            self.preprocessor_ = copy.deepcopy(state['preprocessor_'])
            self.postprocessor_ = copy.deepcopy(state['postprocessor_'])
            if 'random_gen_' in state:
                self.random_gen_ = copy.deepcopy(state['random_gen_'])
            else:
                self.random_gen_ = np.random.default_rng(
                    seed=(self.random_seed if hasattr(self, 'random_seed')
                          else None)
                )
            self.deep_ensemble_ = []
            for alg_id in range(self.ensemble_size):
                model_name = self.names_of_deep_ensemble_[alg_id]
                new_model = build_neural_network(
                    input_size=self.feature_vector_size_,
                    layer_size=self.hidden_layer_size,
                    n_classes=self.n_classes_,
                    n_layers=self.n_layers,
                    dropout_rate=self.dropout_rate,
                    scale_coeff=self.postprocessor_.scale_[0],
                    nn_name=model_name
                )
                new_model.build(input_shape=(None, self.feature_vector_size_))
                new_model.set_weights(state['deep_ensemble_'][alg_id])
                self.deep_ensemble_.append(new_model)
        return self

    @staticmethod
    def check_integer_param(param_name: str, **kwargs):
        if param_name not in kwargs:
            raise ValueError(f'`{param_name}` is not specified!')
        if (not isinstance(kwargs[param_name], int)) and \
                (not isinstance(kwargs[param_name], np.int64)) and \
                (not isinstance(kwargs[param_name], np.uint64)) and \
                (not isinstance(kwargs[param_name], np.int16)) and \
                (not isinstance(kwargs[param_name], np.uint16)) and \
                (not isinstance(kwargs[param_name], np.int8)) and \
                (not isinstance(kwargs[param_name], np.uint8)) and \
                (not isinstance(kwargs[param_name], np.int32)) and \
                (not isinstance(kwargs[param_name], np.uint32)):
            err_msg = f'`{param_name}` is wrong! Expected `{type(3)}`, ' \
                      f'got `{type(kwargs[param_name])}`.'
            raise ValueError(err_msg)
        if kwargs[param_name] < 1:
            err_msg = f'`{param_name}` is wrong! Expected a positive ' \
                      f'integer value, but {kwargs[param_name]} is ' \
                      f'not positive.'
            raise ValueError(err_msg)

    @staticmethod
    def check_boolean_param(param_name: str, **kwargs):
        if param_name not in kwargs:
            raise ValueError(f'`{param_name}` is not specified!')
        if (not isinstance(kwargs[param_name], int)) and \
                (not isinstance(kwargs[param_name], bool)) and \
                (not isinstance(kwargs[param_name], np.bool)) and \
                (not isinstance(kwargs[param_name], np.int64)) and \
                (not isinstance(kwargs[param_name], np.uint64)) and \
                (not isinstance(kwargs[param_name], np.int16)) and \
                (not isinstance(kwargs[param_name], np.uint16)) and \
                (not isinstance(kwargs[param_name], np.int8)) and \
                (not isinstance(kwargs[param_name], np.uint8)) and \
                (not isinstance(kwargs[param_name], np.int32)) and \
                (not isinstance(kwargs[param_name], np.uint32)):
            err_msg = f'`{param_name}` is wrong! Expected `{type(True)}`, ' \
                      f'got `{type(kwargs[param_name])}`.'
            raise ValueError(err_msg)

    @staticmethod
    def check_float_param(param_name: str, **kwargs):
        if param_name not in kwargs:
            raise ValueError(f'`{param_name}` is not specified!')
        if (not isinstance(kwargs[param_name], float)) and \
                (not isinstance(kwargs[param_name], np.float)) and \
                (not isinstance(kwargs[param_name], np.float16)) and \
                (not isinstance(kwargs[param_name], np.float8)) and \
                (not isinstance(kwargs[param_name], np.float32)):
            err_msg = f'`{param_name}` is wrong! Expected `{type(2.3)}`, ' \
                      f'got `{type(kwargs[param_name])}`.'
            raise ValueError(err_msg)

    @staticmethod
    def check_params(**kwargs):
        SNNRegressor.check_integer_param('minibatch_size', **kwargs)
        SNNRegressor.check_integer_param('patience', **kwargs)
        SNNRegressor.check_integer_param('ensemble_size', **kwargs)
        SNNRegressor.check_integer_param('hidden_layer_size', **kwargs)
        SNNRegressor.check_integer_param('n_layers', **kwargs)
        SNNRegressor.check_integer_param('max_epochs', **kwargs)
        SNNRegressor.check_boolean_param('verbose', **kwargs)
        SNNRegressor.check_boolean_param('clear_session', **kwargs)
        SNNRegressor.check_float_param('dropout_rate', **kwargs)
        SNNRegressor.check_float_param('validation_fraction', **kwargs)
        if kwargs['dropout_rate'] < 0.0:
            err_msg = f'`dropout_rate` is wrong! Expected a non-negative ' \
                      f'value, but {kwargs["dropout_rate"]} is negative!'
            raise ValueError(err_msg)
        if kwargs['validation_fraction'] <= 0.0:
            err_msg = f'`validation_fraction` is wrong! Expected a ' \
                      f'floating-point value in (0.0, 1.0), ' \
                      f'but {kwargs["validation_fraction"]} is inadmissible!'
            raise ValueError(err_msg)
        if kwargs['validation_fraction'] >= 1.0:
            err_msg = f'`validation_fraction` is wrong! Expected a ' \
                      f'floating-point value in (0.0, 1.0), ' \
                      f'but {kwargs["validation_fraction"]} is inadmissible!'
            raise ValueError(err_msg)
        if 'random_seed' in kwargs:
            if kwargs['random_seed'] is not None:
                SNNRegressor.check_integer_param('random_seed', **kwargs)

# %%
import numpy as np
import torch
import scipy
import torch.nn as nn
from scipy.spatial import distance_matrix
from torch.utils.data import Dataset
from time import time
from IPython.display import clear_output
import matplotlib.pyplot as plt
import librosa
import pandas as pd
import glob
# %matplotlib inline
import os
from sklearn import preprocessing
import torch
import requests
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from matplotlib import pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from sklearn.utils import shuffle
from torch.utils.data import DataLoader
from IPython.display import clear_output
import numpy as np
from sklearn.linear_model import LinearRegression, BayesianRidge, Ridge
from sklearn.model_selection import train_test_split
import numpy as np, pandas as pd
import matplotlib.pyplot as plt

from sklearn import linear_model
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_boston
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
pip install tensorflow_addons
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.17.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 34.2 MB/s
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (2.7.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->tensorflow_addons) (3.0.9)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.17.1

# %%
X, y = torch.load('dat')

# %%
import torch

# %%
snn = SNNRegressor(minibatch_size = 128, n_layers = 6,ensemble_size = 6, verbose = True)

# %%
snn.fit(X, y)
# Out:
# Class 00:    6 samples
# Class 01:    2 samples
# Class 02:   35 samples
# Class 03:   53 samples
# Class 04:   37 samples
# Class 05:   17 samples
# Class 06:  184 samples
# Class 07: 1938 samples
# Class 08: 2098 samples
# Class 09: 3464 samples
# Class 10:  213 samples
# Class 11: 2007 samples
# Class 12: 4921 samples
# Class 13: 5366 samples
# Class 14: 6713 samples
# Class 15: 7790 samples
# Class 16: 5156 samples
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:680: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=10.
#   UserWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:680: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=10.
#   UserWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:680: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=10.
#   UserWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:680: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=10.
#   UserWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:680: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=10.
#   UserWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py:680: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=10.
#   UserWarning,
# ====================
# NEURAL NETWORK 1
# ====================
#
# Model: "snn_regressor_1_e57e3e74"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  snn_regressor_1_e57e3e74_featu  [(None, 768)]       0           []
#  re_vector (InputLayer)
#
#  snn_regressor_1_e57e3e74_dropo  (None, 768)         0           ['snn_regressor_1_e57e3e74_featur
#  ut1 (AlphaDropout)                                              e_vector[0][0]']
#
#  snn_regressor_1_e57e3e74_dense  (None, 256)         196864      ['snn_regressor_1_e57e3e74_dropou
#  1 (Dense)                                                       t1[0][0]']
#
#  snn_regressor_1_e57e3e74_dropo  (None, 256)         0           ['snn_regressor_1_e57e3e74_dense1
#  ut2 (AlphaDropout)                                              [0][0]']
#
#  snn_regressor_1_e57e3e74_dense  (None, 256)         65792       ['snn_regressor_1_e57e3e74_dropou
#  2 (Dense)                                                       t2[0][0]']
#
#  snn_regressor_1_e57e3e74_dropo  (None, 256)         0           ['snn_regressor_1_e57e3e74_dense2
#  ut3 (AlphaDropout)                                              [0][0]']
#
#  snn_regressor_1_e57e3e74_dense  (None, 256)         65792       ['snn_regressor_1_e57e3e74_dropou
#  3 (Dense)                                                       t3[0][0]']
#
#  snn_regressor_1_e57e3e74_dropo  (None, 256)         0           ['snn_regressor_1_e57e3e74_dense3
#  ut4 (AlphaDropout)                                              [0][0]']
#
#  snn_regressor_1_e57e3e74_dense  (None, 256)         65792       ['snn_regressor_1_e57e3e74_dropou
#  4 (Dense)                                                       t4[0][0]']
#
#  snn_regressor_1_e57e3e74_dropo  (None, 256)         0           ['snn_regressor_1_e57e3e74_dense4
#  ut5 (AlphaDropout)                                              [0][0]']
#
#  snn_regressor_1_e57e3e74_dense  (None, 256)         65792       ['snn_regressor_1_e57e3e74_dropou
#  5 (Dense)                                                       t5[0][0]']
#
#  snn_regressor_1_e57e3e74_dropo  (None, 256)         0           ['snn_regressor_1_e57e3e74_dense5
#  ut6 (AlphaDropout)                                              [0][0]']
#
#  snn_regressor_1_e57e3e74_dense  (None, 256)         65792       ['snn_regressor_1_e57e3e74_dropou
#  6 (Dense)                                                       t6[0][0]']
#
#  snn_regressor_1_e57e3e74_dropo  (None, 256)         0           ['snn_regressor_1_e57e3e74_dense6
#  ut7 (AlphaDropout)                                              [0][0]']
#
#  snn_regressor_1_e57e3e74_regre  (None, 1)           257         ['snn_regressor_1_e57e3e74_dropou
#  ssion (Dense)                                                   t7[0][0]']
#
#  snn_regressor_1_e57e3e74_class  (None, 17)          4369        ['snn_regressor_1_e57e3e74_dropou
#  ification (Dense)                                               t5[0][0]']
#
# ==================================================================================================
# Total params: 530,450
# Trainable params: 530,450
# Non-trainable params: 0
# __________________________________________________________________________________________________
#
# Epoch 1/1000
# 281/281 - 7s - loss: 1.0299 - snn_regressor_1_e57e3e74_regression_loss: 0.3097 - snn_regressor_1_e57e3e74_classification_loss: 1.4404 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.3097 - val_loss: 0.4835 - val_snn_regressor_1_e57e3e74_regression_loss: 0.1891 - val_snn_regressor_1_e57e3e74_classification_loss: 0.5889 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.1891 - 7s/epoch - 26ms/step
# Epoch 2/1000
# 281/281 - 3s - loss: 0.3452 - snn_regressor_1_e57e3e74_regression_loss: 0.1321 - snn_regressor_1_e57e3e74_classification_loss: 0.4263 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.1321 - val_loss: 0.2714 - val_snn_regressor_1_e57e3e74_regression_loss: 0.1035 - val_snn_regressor_1_e57e3e74_classification_loss: 0.3357 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.1035 - 3s/epoch - 12ms/step
# Epoch 3/1000
# 281/281 - 3s - loss: 0.2344 - snn_regressor_1_e57e3e74_regression_loss: 0.0977 - snn_regressor_1_e57e3e74_classification_loss: 0.2735 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0977 - val_loss: 0.2386 - val_snn_regressor_1_e57e3e74_regression_loss: 0.1096 - val_snn_regressor_1_e57e3e74_classification_loss: 0.2580 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.1096 - 3s/epoch - 12ms/step
# Epoch 4/1000
# 281/281 - 3s - loss: 0.1963 - snn_regressor_1_e57e3e74_regression_loss: 0.0876 - snn_regressor_1_e57e3e74_classification_loss: 0.2174 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0876 - val_loss: 0.1850 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0774 - val_snn_regressor_1_e57e3e74_classification_loss: 0.2152 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0774 - 3s/epoch - 12ms/step
# Epoch 5/1000
# 281/281 - 4s - loss: 0.1644 - snn_regressor_1_e57e3e74_regression_loss: 0.0750 - snn_regressor_1_e57e3e74_classification_loss: 0.1789 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0750 - val_loss: 0.1660 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0702 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1916 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0702 - 4s/epoch - 13ms/step
# Epoch 6/1000
# 281/281 - 3s - loss: 0.1480 - snn_regressor_1_e57e3e74_regression_loss: 0.0688 - snn_regressor_1_e57e3e74_classification_loss: 0.1585 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0688 - val_loss: 0.1264 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0409 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1710 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0409 - 3s/epoch - 12ms/step
# Epoch 7/1000
# 281/281 - 3s - loss: 0.1389 - snn_regressor_1_e57e3e74_regression_loss: 0.0663 - snn_regressor_1_e57e3e74_classification_loss: 0.1452 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0663 - val_loss: 0.1485 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0705 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1561 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0705 - 3s/epoch - 12ms/step
# Epoch 8/1000
# 281/281 - 3s - loss: 0.1292 - snn_regressor_1_e57e3e74_regression_loss: 0.0623 - snn_regressor_1_e57e3e74_classification_loss: 0.1338 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0623 - val_loss: 0.1274 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0529 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1490 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0529 - 3s/epoch - 12ms/step
# Epoch 9/1000
# 281/281 - 3s - loss: 0.1157 - snn_regressor_1_e57e3e74_regression_loss: 0.0533 - snn_regressor_1_e57e3e74_classification_loss: 0.1249 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0533 - val_loss: 0.1246 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0539 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1415 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0539 - 3s/epoch - 12ms/step
# Epoch 10/1000
# 281/281 - 3s - loss: 0.1183 - snn_regressor_1_e57e3e74_regression_loss: 0.0573 - snn_regressor_1_e57e3e74_classification_loss: 0.1219 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0573 - val_loss: 0.1258 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0576 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1364 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0576 - 3s/epoch - 12ms/step
# Epoch 11/1000
# 281/281 - 3s - loss: 0.1081 - snn_regressor_1_e57e3e74_regression_loss: 0.0488 - snn_regressor_1_e57e3e74_classification_loss: 0.1187 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0488 - val_loss: 0.1078 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0453 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1250 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0453 - 3s/epoch - 12ms/step
# Epoch 12/1000
# 281/281 - 3s - loss: 0.1028 - snn_regressor_1_e57e3e74_regression_loss: 0.0475 - snn_regressor_1_e57e3e74_classification_loss: 0.1106 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0475 - val_loss: 0.0892 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0275 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1233 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0275 - 3s/epoch - 12ms/step
# Epoch 13/1000
# 281/281 - 3s - loss: 0.0962 - snn_regressor_1_e57e3e74_regression_loss: 0.0430 - snn_regressor_1_e57e3e74_classification_loss: 0.1065 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0430 - val_loss: 0.0992 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0367 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1249 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0367 - 3s/epoch - 12ms/step
# Epoch 14/1000
# 281/281 - 3s - loss: 0.0946 - snn_regressor_1_e57e3e74_regression_loss: 0.0406 - snn_regressor_1_e57e3e74_classification_loss: 0.1079 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0406 - val_loss: 0.0937 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0287 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1299 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0287 - 3s/epoch - 12ms/step
# Epoch 15/1000
# 281/281 - 3s - loss: 0.0913 - snn_regressor_1_e57e3e74_regression_loss: 0.0387 - snn_regressor_1_e57e3e74_classification_loss: 0.1052 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0387 - val_loss: 0.0984 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0255 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1458 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0255 - 3s/epoch - 12ms/step
# Epoch 16/1000
# 281/281 - 3s - loss: 0.0912 - snn_regressor_1_e57e3e74_regression_loss: 0.0373 - snn_regressor_1_e57e3e74_classification_loss: 0.1076 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0373 - val_loss: 0.0911 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0329 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1163 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0329 - 3s/epoch - 12ms/step
# Epoch 17/1000
# 281/281 - 3s - loss: 0.0840 - snn_regressor_1_e57e3e74_regression_loss: 0.0342 - snn_regressor_1_e57e3e74_classification_loss: 0.0995 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0342 - val_loss: 0.1018 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0460 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1117 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0460 - 3s/epoch - 12ms/step
# Epoch 18/1000
# 281/281 - 3s - loss: 0.0816 - snn_regressor_1_e57e3e74_regression_loss: 0.0328 - snn_regressor_1_e57e3e74_classification_loss: 0.0977 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0328 - val_loss: 0.0877 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0305 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1144 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0305 - 3s/epoch - 12ms/step
# Epoch 19/1000
# 281/281 - 3s - loss: 0.0806 - snn_regressor_1_e57e3e74_regression_loss: 0.0307 - snn_regressor_1_e57e3e74_classification_loss: 0.0998 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0307 - val_loss: 0.1132 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0553 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1157 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0553 - 3s/epoch - 12ms/step
# Epoch 20/1000
# 281/281 - 3s - loss: 0.0771 - snn_regressor_1_e57e3e74_regression_loss: 0.0300 - snn_regressor_1_e57e3e74_classification_loss: 0.0942 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0300 - val_loss: 0.0974 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0403 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1142 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0403 - 3s/epoch - 12ms/step
# Epoch 21/1000
# 281/281 - 3s - loss: 0.0776 - snn_regressor_1_e57e3e74_regression_loss: 0.0299 - snn_regressor_1_e57e3e74_classification_loss: 0.0954 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0299 - val_loss: 0.0984 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0419 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1130 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0419 - 3s/epoch - 12ms/step
# Epoch 22/1000
# 281/281 - 3s - loss: 0.0750 - snn_regressor_1_e57e3e74_regression_loss: 0.0277 - snn_regressor_1_e57e3e74_classification_loss: 0.0947 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0277 - val_loss: 0.0907 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0271 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1272 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0271 - 3s/epoch - 12ms/step
# Epoch 23/1000
# 281/281 - 3s - loss: 0.0771 - snn_regressor_1_e57e3e74_regression_loss: 0.0280 - snn_regressor_1_e57e3e74_classification_loss: 0.0983 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0280 - val_loss: 0.0792 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0221 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1142 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0221 - 3s/epoch - 12ms/step
# Epoch 24/1000
# 281/281 - 3s - loss: 0.0739 - snn_regressor_1_e57e3e74_regression_loss: 0.0269 - snn_regressor_1_e57e3e74_classification_loss: 0.0939 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0269 - val_loss: 0.0687 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0150 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1074 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0150 - 3s/epoch - 12ms/step
# Epoch 25/1000
# 281/281 - 3s - loss: 0.0777 - snn_regressor_1_e57e3e74_regression_loss: 0.0257 - snn_regressor_1_e57e3e74_classification_loss: 0.1038 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0257 - val_loss: 0.0770 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0211 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1117 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0211 - 3s/epoch - 12ms/step
# Epoch 26/1000
# 281/281 - 3s - loss: 0.0695 - snn_regressor_1_e57e3e74_regression_loss: 0.0234 - snn_regressor_1_e57e3e74_classification_loss: 0.0921 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0234 - val_loss: 0.0776 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0226 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1101 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0226 - 3s/epoch - 12ms/step
# Epoch 27/1000
# 281/281 - 3s - loss: 0.0660 - snn_regressor_1_e57e3e74_regression_loss: 0.0217 - snn_regressor_1_e57e3e74_classification_loss: 0.0887 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0217 - val_loss: 0.0798 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0211 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1173 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0211 - 3s/epoch - 12ms/step
# Epoch 28/1000
# 281/281 - 3s - loss: 0.0681 - snn_regressor_1_e57e3e74_regression_loss: 0.0220 - snn_regressor_1_e57e3e74_classification_loss: 0.0922 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0220 - val_loss: 0.0785 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0250 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1071 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0250 - 3s/epoch - 12ms/step
# Epoch 29/1000
# 281/281 - 3s - loss: 0.0690 - snn_regressor_1_e57e3e74_regression_loss: 0.0211 - snn_regressor_1_e57e3e74_classification_loss: 0.0958 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0211 - val_loss: 0.0715 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0175 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1080 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0175 - 3s/epoch - 12ms/step
# Epoch 30/1000
# 281/281 - 3s - loss: 0.0654 - snn_regressor_1_e57e3e74_regression_loss: 0.0204 - snn_regressor_1_e57e3e74_classification_loss: 0.0900 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0204 - val_loss: 0.0653 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0143 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1020 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0143 - 3s/epoch - 12ms/step
# Epoch 31/1000
# 281/281 - 3s - loss: 0.0613 - snn_regressor_1_e57e3e74_regression_loss: 0.0184 - snn_regressor_1_e57e3e74_classification_loss: 0.0857 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0184 - val_loss: 0.0869 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0341 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1057 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0341 - 3s/epoch - 12ms/step
# Epoch 32/1000
# 281/281 - 3s - loss: 0.0644 - snn_regressor_1_e57e3e74_regression_loss: 0.0205 - snn_regressor_1_e57e3e74_classification_loss: 0.0878 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0205 - val_loss: 0.0837 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0297 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1081 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0297 - 3s/epoch - 12ms/step
# Epoch 33/1000
# 281/281 - 3s - loss: 0.0660 - snn_regressor_1_e57e3e74_regression_loss: 0.0192 - snn_regressor_1_e57e3e74_classification_loss: 0.0936 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0192 - val_loss: 0.0820 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0197 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1246 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0197 - 3s/epoch - 12ms/step
# Epoch 34/1000
# 281/281 - 3s - loss: 0.0637 - snn_regressor_1_e57e3e74_regression_loss: 0.0192 - snn_regressor_1_e57e3e74_classification_loss: 0.0891 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0192 - val_loss: 0.0711 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0168 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1087 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0168 - 3s/epoch - 12ms/step
# Epoch 35/1000
# 281/281 - 3s - loss: 0.0626 - snn_regressor_1_e57e3e74_regression_loss: 0.0171 - snn_regressor_1_e57e3e74_classification_loss: 0.0910 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0171 - val_loss: 0.0789 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0183 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1212 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0183 - 3s/epoch - 12ms/step
# Epoch 36/1000
# 281/281 - 3s - loss: 0.0624 - snn_regressor_1_e57e3e74_regression_loss: 0.0175 - snn_regressor_1_e57e3e74_classification_loss: 0.0898 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0175 - val_loss: 0.0629 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0116 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1025 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0116 - 3s/epoch - 12ms/step
# Epoch 37/1000
# 281/281 - 3s - loss: 0.0627 - snn_regressor_1_e57e3e74_regression_loss: 0.0169 - snn_regressor_1_e57e3e74_classification_loss: 0.0916 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0169 - val_loss: 0.0736 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0171 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1130 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0171 - 3s/epoch - 12ms/step
# Epoch 38/1000
# 281/281 - 3s - loss: 0.0603 - snn_regressor_1_e57e3e74_regression_loss: 0.0167 - snn_regressor_1_e57e3e74_classification_loss: 0.0871 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0167 - val_loss: 0.0688 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0167 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1044 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0167 - 3s/epoch - 12ms/step
# Epoch 39/1000
# 281/281 - 3s - loss: 0.0591 - snn_regressor_1_e57e3e74_regression_loss: 0.0154 - snn_regressor_1_e57e3e74_classification_loss: 0.0873 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0154 - val_loss: 0.0751 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0226 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1051 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0226 - 3s/epoch - 12ms/step
# Epoch 40/1000
# 281/281 - 3s - loss: 0.0593 - snn_regressor_1_e57e3e74_regression_loss: 0.0154 - snn_regressor_1_e57e3e74_classification_loss: 0.0876 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0154 - val_loss: 0.0699 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0153 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1091 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0153 - 3s/epoch - 12ms/step
# Epoch 41/1000
# 281/281 - 3s - loss: 0.0601 - snn_regressor_1_e57e3e74_regression_loss: 0.0156 - snn_regressor_1_e57e3e74_classification_loss: 0.0892 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0156 - val_loss: 0.0686 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0175 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1021 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0175 - 3s/epoch - 12ms/step
# Epoch 42/1000
# 281/281 - 3s - loss: 0.0587 - snn_regressor_1_e57e3e74_regression_loss: 0.0157 - snn_regressor_1_e57e3e74_classification_loss: 0.0860 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0157 - val_loss: 0.0674 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0171 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1006 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0171 - 3s/epoch - 12ms/step
# Epoch 43/1000
# 281/281 - 3s - loss: 0.0589 - snn_regressor_1_e57e3e74_regression_loss: 0.0144 - snn_regressor_1_e57e3e74_classification_loss: 0.0889 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0144 - val_loss: 0.0727 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0140 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1173 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0140 - 3s/epoch - 12ms/step
# Epoch 44/1000
# 281/281 - 3s - loss: 0.0583 - snn_regressor_1_e57e3e74_regression_loss: 0.0148 - snn_regressor_1_e57e3e74_classification_loss: 0.0871 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0148 - val_loss: 0.0627 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0118 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1018 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0118 - 3s/epoch - 12ms/step
# Epoch 45/1000
# 281/281 - 3s - loss: 0.0573 - snn_regressor_1_e57e3e74_regression_loss: 0.0139 - snn_regressor_1_e57e3e74_classification_loss: 0.0869 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0139 - val_loss: 0.0752 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0162 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1180 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0162 - 3s/epoch - 12ms/step
# Epoch 46/1000
# 281/281 - 3s - loss: 0.0563 - snn_regressor_1_e57e3e74_regression_loss: 0.0136 - snn_regressor_1_e57e3e74_classification_loss: 0.0854 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0136 - val_loss: 0.0607 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0119 - val_snn_regressor_1_e57e3e74_classification_loss: 0.0976 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0119 - 3s/epoch - 12ms/step
# Epoch 47/1000
# 281/281 - 3s - loss: 0.0559 - snn_regressor_1_e57e3e74_regression_loss: 0.0135 - snn_regressor_1_e57e3e74_classification_loss: 0.0849 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0135 - val_loss: 0.0584 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0098 - val_snn_regressor_1_e57e3e74_classification_loss: 0.0973 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0098 - 3s/epoch - 12ms/step
# Epoch 48/1000
# 281/281 - 3s - loss: 0.0574 - snn_regressor_1_e57e3e74_regression_loss: 0.0137 - snn_regressor_1_e57e3e74_classification_loss: 0.0874 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0137 - val_loss: 0.0650 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0093 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1114 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0093 - 3s/epoch - 12ms/step
# Epoch 49/1000
# 281/281 - 3s - loss: 0.0561 - snn_regressor_1_e57e3e74_regression_loss: 0.0125 - snn_regressor_1_e57e3e74_classification_loss: 0.0872 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0125 - val_loss: 0.0690 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0152 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1075 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0152 - 3s/epoch - 12ms/step
# Epoch 50/1000
# 281/281 - 3s - loss: 0.0590 - snn_regressor_1_e57e3e74_regression_loss: 0.0132 - snn_regressor_1_e57e3e74_classification_loss: 0.0917 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0132 - val_loss: 0.0628 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0116 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1024 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0116 - 3s/epoch - 12ms/step
# Epoch 51/1000
# 281/281 - 3s - loss: 0.0548 - snn_regressor_1_e57e3e74_regression_loss: 0.0120 - snn_regressor_1_e57e3e74_classification_loss: 0.0856 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0120 - val_loss: 0.0619 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0130 - val_snn_regressor_1_e57e3e74_classification_loss: 0.0977 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0130 - 3s/epoch - 12ms/step
# Epoch 52/1000
# 281/281 - 3s - loss: 0.0552 - snn_regressor_1_e57e3e74_regression_loss: 0.0132 - snn_regressor_1_e57e3e74_classification_loss: 0.0840 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0132 - val_loss: 0.0650 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0163 - val_snn_regressor_1_e57e3e74_classification_loss: 0.0975 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0163 - 3s/epoch - 12ms/step
# Epoch 53/1000
# 281/281 - 3s - loss: 0.0537 - snn_regressor_1_e57e3e74_regression_loss: 0.0121 - snn_regressor_1_e57e3e74_classification_loss: 0.0832 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0121 - val_loss: 0.0601 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0094 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1015 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0094 - 3s/epoch - 12ms/step
# Epoch 54/1000
# 281/281 - 3s - loss: 0.0588 - snn_regressor_1_e57e3e74_regression_loss: 0.0126 - snn_regressor_1_e57e3e74_classification_loss: 0.0924 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0126 - val_loss: 0.0653 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0089 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1127 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0089 - 3s/epoch - 12ms/step
# Epoch 55/1000
# 281/281 - 3s - loss: 0.0558 - snn_regressor_1_e57e3e74_regression_loss: 0.0120 - snn_regressor_1_e57e3e74_classification_loss: 0.0875 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0120 - val_loss: 0.0636 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0135 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1003 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0135 - 3s/epoch - 12ms/step
# Epoch 56/1000
# 281/281 - 3s - loss: 0.0543 - snn_regressor_1_e57e3e74_regression_loss: 0.0116 - snn_regressor_1_e57e3e74_classification_loss: 0.0854 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0116 - val_loss: 0.0659 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0155 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1009 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0155 - 3s/epoch - 12ms/step
# Epoch 57/1000
# 281/281 - 3s - loss: 0.0520 - snn_regressor_1_e57e3e74_regression_loss: 0.0104 - snn_regressor_1_e57e3e74_classification_loss: 0.0832 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0104 - val_loss: 0.0612 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0091 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1043 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0091 - 3s/epoch - 12ms/step
# Epoch 58/1000
# 281/281 - 3s - loss: 0.0559 - snn_regressor_1_e57e3e74_regression_loss: 0.0124 - snn_regressor_1_e57e3e74_classification_loss: 0.0870 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0124 - val_loss: 0.0656 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0143 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1026 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0143 - 3s/epoch - 12ms/step
# Epoch 59/1000
# 281/281 - 3s - loss: 0.0541 - snn_regressor_1_e57e3e74_regression_loss: 0.0111 - snn_regressor_1_e57e3e74_classification_loss: 0.0859 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0111 - val_loss: 0.0659 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0138 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1041 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0138 - 3s/epoch - 12ms/step
# Epoch 60/1000
# 281/281 - 3s - loss: 0.0545 - snn_regressor_1_e57e3e74_regression_loss: 0.0111 - snn_regressor_1_e57e3e74_classification_loss: 0.0867 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0111 - val_loss: 0.0577 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0075 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1004 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0075 - 3s/epoch - 12ms/step
# Epoch 61/1000
# 281/281 - 3s - loss: 0.0529 - snn_regressor_1_e57e3e74_regression_loss: 0.0108 - snn_regressor_1_e57e3e74_classification_loss: 0.0841 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0108 - val_loss: 0.0628 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0129 - val_snn_regressor_1_e57e3e74_classification_loss: 0.0998 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0129 - 3s/epoch - 12ms/step
# Epoch 62/1000
# 281/281 - 3s - loss: 0.0538 - snn_regressor_1_e57e3e74_regression_loss: 0.0105 - snn_regressor_1_e57e3e74_classification_loss: 0.0865 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0105 - val_loss: 0.0605 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0118 - val_snn_regressor_1_e57e3e74_classification_loss: 0.0974 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0118 - 3s/epoch - 12ms/step
# Epoch 63/1000
# 281/281 - 3s - loss: 0.0541 - snn_regressor_1_e57e3e74_regression_loss: 0.0103 - snn_regressor_1_e57e3e74_classification_loss: 0.0877 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0103 - val_loss: 0.0683 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0140 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1085 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0140 - 3s/epoch - 12ms/step
# Epoch 64/1000
# 281/281 - 3s - loss: 0.0547 - snn_regressor_1_e57e3e74_regression_loss: 0.0111 - snn_regressor_1_e57e3e74_classification_loss: 0.0871 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0111 - val_loss: 0.0619 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0126 - val_snn_regressor_1_e57e3e74_classification_loss: 0.0986 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0126 - 3s/epoch - 12ms/step
# Epoch 65/1000
# 281/281 - 3s - loss: 0.0546 - snn_regressor_1_e57e3e74_regression_loss: 0.0107 - snn_regressor_1_e57e3e74_classification_loss: 0.0878 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0107 - val_loss: 0.0604 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0126 - val_snn_regressor_1_e57e3e74_classification_loss: 0.0957 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0126 - 3s/epoch - 12ms/step
# Epoch 66/1000
# 281/281 - 3s - loss: 0.0507 - snn_regressor_1_e57e3e74_regression_loss: 0.0092 - snn_regressor_1_e57e3e74_classification_loss: 0.0830 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0092 - val_loss: 0.0576 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0094 - val_snn_regressor_1_e57e3e74_classification_loss: 0.0965 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0094 - 3s/epoch - 12ms/step
# Epoch 67/1000
# 281/281 - 3s - loss: 0.0514 - snn_regressor_1_e57e3e74_regression_loss: 0.0098 - snn_regressor_1_e57e3e74_classification_loss: 0.0831 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0098 - val_loss: 0.0574 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0109 - val_snn_regressor_1_e57e3e74_classification_loss: 0.0930 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0109 - 3s/epoch - 12ms/step
# Epoch 68/1000
# 281/281 - 3s - loss: 0.0519 - snn_regressor_1_e57e3e74_regression_loss: 0.0099 - snn_regressor_1_e57e3e74_classification_loss: 0.0840 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0099 - val_loss: 0.0600 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0097 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1005 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0097 - 3s/epoch - 12ms/step
# Epoch 69/1000
# 281/281 - 3s - loss: 0.0503 - snn_regressor_1_e57e3e74_regression_loss: 0.0089 - snn_regressor_1_e57e3e74_classification_loss: 0.0827 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0089 - val_loss: 0.0597 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0106 - val_snn_regressor_1_e57e3e74_classification_loss: 0.0982 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0106 - 3s/epoch - 12ms/step
# Epoch 70/1000
# 281/281 - 3s - loss: 0.0537 - snn_regressor_1_e57e3e74_regression_loss: 0.0097 - snn_regressor_1_e57e3e74_classification_loss: 0.0879 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0097 - val_loss: 0.0648 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0113 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1069 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0113 - 3s/epoch - 12ms/step
# Epoch 71/1000
# 281/281 - 3s - loss: 0.0533 - snn_regressor_1_e57e3e74_regression_loss: 0.0103 - snn_regressor_1_e57e3e74_classification_loss: 0.0860 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0103 - val_loss: 0.0593 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0082 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1024 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0082 - 3s/epoch - 12ms/step
# Epoch 72/1000
# 281/281 - 3s - loss: 0.0527 - snn_regressor_1_e57e3e74_regression_loss: 0.0099 - snn_regressor_1_e57e3e74_classification_loss: 0.0857 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0099 - val_loss: 0.0585 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0081 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1009 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0081 - 3s/epoch - 12ms/step
# Epoch 73/1000
# 281/281 - 3s - loss: 0.0526 - snn_regressor_1_e57e3e74_regression_loss: 0.0096 - snn_regressor_1_e57e3e74_classification_loss: 0.0860 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0096 - val_loss: 0.0572 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0077 - val_snn_regressor_1_e57e3e74_classification_loss: 0.0989 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0077 - 3s/epoch - 12ms/step
# Epoch 74/1000
# 281/281 - 3s - loss: 0.0525 - snn_regressor_1_e57e3e74_regression_loss: 0.0096 - snn_regressor_1_e57e3e74_classification_loss: 0.0858 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0096 - val_loss: 0.0599 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0097 - val_snn_regressor_1_e57e3e74_classification_loss: 0.1004 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0097 - 3s/epoch - 12ms/step
# Epoch 75/1000
# Restoring model weights from the end of the best epoch: 60.
# 281/281 - 3s - loss: 0.0506 - snn_regressor_1_e57e3e74_regression_loss: 0.0090 - snn_regressor_1_e57e3e74_classification_loss: 0.0830 - snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0090 - val_loss: 0.0599 - val_snn_regressor_1_e57e3e74_regression_loss: 0.0107 - val_snn_regressor_1_e57e3e74_classification_loss: 0.0985 - val_snn_regressor_1_e57e3e74_regression_mean_absolute_error: 0.0107 - 3s/epoch - 12ms/step
# Epoch 75: early stopping
# ====================
# NEURAL NETWORK 2
# ====================
#
# Model: "snn_regressor_2_840c1a84"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  snn_regressor_2_840c1a84_featu  [(None, 768)]       0           []
#  re_vector (InputLayer)
#
#  snn_regressor_2_840c1a84_dropo  (None, 768)         0           ['snn_regressor_2_840c1a84_featur
#  ut1 (AlphaDropout)                                              e_vector[0][0]']
#
#  snn_regressor_2_840c1a84_dense  (None, 256)         196864      ['snn_regressor_2_840c1a84_dropou
#  1 (Dense)                                                       t1[0][0]']
#
#  snn_regressor_2_840c1a84_dropo  (None, 256)         0           ['snn_regressor_2_840c1a84_dense1
#  ut2 (AlphaDropout)                                              [0][0]']
#
#  snn_regressor_2_840c1a84_dense  (None, 256)         65792       ['snn_regressor_2_840c1a84_dropou
#  2 (Dense)                                                       t2[0][0]']
#
#  snn_regressor_2_840c1a84_dropo  (None, 256)         0           ['snn_regressor_2_840c1a84_dense2
#  ut3 (AlphaDropout)                                              [0][0]']
#
#  snn_regressor_2_840c1a84_dense  (None, 256)         65792       ['snn_regressor_2_840c1a84_dropou
#  3 (Dense)                                                       t3[0][0]']
#
#  snn_regressor_2_840c1a84_dropo  (None, 256)         0           ['snn_regressor_2_840c1a84_dense3
#  ut4 (AlphaDropout)                                              [0][0]']
#
#  snn_regressor_2_840c1a84_dense  (None, 256)         65792       ['snn_regressor_2_840c1a84_dropou
#  4 (Dense)                                                       t4[0][0]']
#
#  snn_regressor_2_840c1a84_dropo  (None, 256)         0           ['snn_regressor_2_840c1a84_dense4
#  ut5 (AlphaDropout)                                              [0][0]']
#
#  snn_regressor_2_840c1a84_dense  (None, 256)         65792       ['snn_regressor_2_840c1a84_dropou
#  5 (Dense)                                                       t5[0][0]']
#
#  snn_regressor_2_840c1a84_dropo  (None, 256)         0           ['snn_regressor_2_840c1a84_dense5
#  ut6 (AlphaDropout)                                              [0][0]']
#
#  snn_regressor_2_840c1a84_dense  (None, 256)         65792       ['snn_regressor_2_840c1a84_dropou
#  6 (Dense)                                                       t6[0][0]']
#
#  snn_regressor_2_840c1a84_dropo  (None, 256)         0           ['snn_regressor_2_840c1a84_dense6
#  ut7 (AlphaDropout)                                              [0][0]']
#
#  snn_regressor_2_840c1a84_regre  (None, 1)           257         ['snn_regressor_2_840c1a84_dropou
#  ssion (Dense)                                                   t7[0][0]']
#
#  snn_regressor_2_840c1a84_class  (None, 17)          4369        ['snn_regressor_2_840c1a84_dropou
#  ification (Dense)                                               t5[0][0]']
#
# ==================================================================================================
# Total params: 530,450
# Trainable params: 530,450
# Non-trainable params: 0
# __________________________________________________________________________________________________
#
# Epoch 1/1000
# 281/281 - 7s - loss: 1.0118 - snn_regressor_2_840c1a84_regression_loss: 0.3125 - snn_regressor_2_840c1a84_classification_loss: 1.3986 - snn_regressor_2_840c1a84_regression_mean_absolute_error: 0.3125 - val_loss: 0.4627 - val_snn_regressor_2_840c1a84_regression_loss: 0.1664 - val_snn_regressor_2_840c1a84_classification_loss: 0.5925 - val_snn_regressor_2_840c1a84_regression_mean_absolute_error: 0.1664 - 7s/epoch - 26ms/step
# Epoch 2/1000
# 281/281 - 3s - loss: 0.3531 - snn_regressor_2_840c1a84_regression_loss: 0.1374 - snn_regressor_2_840c1a84_classification_loss: 0.4314 - snn_regressor_2_840c1a84_regression_mean_absolute_error: 0.1374 - val_loss: 0.2668 - val_snn_regressor_2_840c1a84_regression_loss: 0.1011 - val_snn_regressor_2_840c1a84_classification_loss: 0.3314 - val_snn_regressor_2_840c1a84_regression_mean_absolute_error: 0.1011 - 3s/epoch - 12ms/step
# Epoch 3/1000
# 281/281 - 3s - loss: 0.2429 - snn_regressor_2_840c1a84_regression_loss: 0.1023 - snn_regressor_2_840c1a84_classification_loss: 0.2811 - snn_regressor_2_840c1a84_regression_mean_absolute_error: 0.1023 - val_loss: 0.2067 - val_snn_regressor_2_840c1a84_regression_loss: 0.0807 - val_snn_regressor_2_840c1a84_classification_loss: 0.2519 - val_snn_regressor_2_840c1a84_regression_mean_absolute_error: 0.0807 - 3s/epoch - 12ms/step
# Epoch 4/1000
# 281/281 - 3s - loss: 0.2041 - snn_regressor_2_840c1a84_regression_loss: 0.0946 - snn_regressor_2_840c1a84_classification_loss: 0.2190 - snn_regressor_2_840c1a84_regression_mean_absolute_error: 0.0946 - val_loss: 0.1624 - val_snn_regressor_2_840c1a84_regression_loss: 0.0615 - val_snn_regressor_2_840c1a84_classification_loss: 0.2017 - val_snn_regressor_2_840c1a84_regression_mean_absolute_error: 0.0615 - 3s/epoch - 12ms/step
# Epoch 5/1000
# 281/281 - 3s - loss: 0.1766 - snn_regressor_2_840c1a84_regression_loss: 0.0857 - snn_regressor_2_840c1a84_classification_loss: 0.1817 - snn_regressor_2_840c1a84_regression_mean_absolute_error: 0.0857 - val_loss: 0.1506 - val_snn_regressor_2_840c1a84_regression_loss: 0.0640 - val_snn_regressor_2_840c1a84_classification_loss: 0.1732 - val_snn_regressor_2_840c1a84_regression_mean_absolute_error: 0.0640 - 3s/epoch - 12ms/step
# Epoch 6/1000
# ...
# 281/281 - 3s - loss: 0.0619 - snn_regressor_6_f38140e0_regression_loss: 0.0184 - snn_regressor_6_f38140e0_classification_loss: 0.0871 - snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0184 - val_loss: 0.0718 - val_snn_regressor_6_f38140e0_regression_loss: 0.0169 - val_snn_regressor_6_f38140e0_classification_loss: 0.1098 - val_snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0169 - 3s/epoch - 12ms/step
# Epoch 41/1000
# 281/281 - 3s - loss: 0.0614 - snn_regressor_6_f38140e0_regression_loss: 0.0170 - snn_regressor_6_f38140e0_classification_loss: 0.0888 - snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0170 - val_loss: 0.0693 - val_snn_regressor_6_f38140e0_regression_loss: 0.0168 - val_snn_regressor_6_f38140e0_classification_loss: 0.1049 - val_snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0168 - 3s/epoch - 12ms/step
# Epoch 42/1000
# 281/281 - 3s - loss: 0.0637 - snn_regressor_6_f38140e0_regression_loss: 0.0179 - snn_regressor_6_f38140e0_classification_loss: 0.0917 - snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0179 - val_loss: 0.0643 - val_snn_regressor_6_f38140e0_regression_loss: 0.0130 - val_snn_regressor_6_f38140e0_classification_loss: 0.1026 - val_snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0130 - 3s/epoch - 12ms/step
# Epoch 43/1000
# 281/281 - 3s - loss: 0.0594 - snn_regressor_6_f38140e0_regression_loss: 0.0161 - snn_regressor_6_f38140e0_classification_loss: 0.0867 - snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0161 - val_loss: 0.0827 - val_snn_regressor_6_f38140e0_regression_loss: 0.0202 - val_snn_regressor_6_f38140e0_classification_loss: 0.1249 - val_snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0202 - 3s/epoch - 12ms/step
# Epoch 44/1000
# 281/281 - 3s - loss: 0.0603 - snn_regressor_6_f38140e0_regression_loss: 0.0158 - snn_regressor_6_f38140e0_classification_loss: 0.0890 - snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0158 - val_loss: 0.0759 - val_snn_regressor_6_f38140e0_regression_loss: 0.0222 - val_snn_regressor_6_f38140e0_classification_loss: 0.1073 - val_snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0222 - 3s/epoch - 12ms/step
# Epoch 45/1000
# 281/281 - 3s - loss: 0.0578 - snn_regressor_6_f38140e0_regression_loss: 0.0152 - snn_regressor_6_f38140e0_classification_loss: 0.0851 - snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0152 - val_loss: 0.0630 - val_snn_regressor_6_f38140e0_regression_loss: 0.0113 - val_snn_regressor_6_f38140e0_classification_loss: 0.1035 - val_snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0113 - 3s/epoch - 12ms/step
# Epoch 46/1000
# 281/281 - 3s - loss: 0.0582 - snn_regressor_6_f38140e0_regression_loss: 0.0155 - snn_regressor_6_f38140e0_classification_loss: 0.0855 - snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0155 - val_loss: 0.0585 - val_snn_regressor_6_f38140e0_regression_loss: 0.0121 - val_snn_regressor_6_f38140e0_classification_loss: 0.0927 - val_snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0121 - 3s/epoch - 12ms/step
# Epoch 47/1000
# 281/281 - 3s - loss: 0.0578 - snn_regressor_6_f38140e0_regression_loss: 0.0146 - snn_regressor_6_f38140e0_classification_loss: 0.0864 - snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0146 - val_loss: 0.0611 - val_snn_regressor_6_f38140e0_regression_loss: 0.0134 - val_snn_regressor_6_f38140e0_classification_loss: 0.0954 - val_snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0134 - 3s/epoch - 12ms/step
# Epoch 48/1000
# 281/281 - 3s - loss: 0.0560 - snn_regressor_6_f38140e0_regression_loss: 0.0145 - snn_regressor_6_f38140e0_classification_loss: 0.0830 - snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0145 - val_loss: 0.0600 - val_snn_regressor_6_f38140e0_regression_loss: 0.0097 - val_snn_regressor_6_f38140e0_classification_loss: 0.1005 - val_snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0097 - 3s/epoch - 12ms/step
# Epoch 49/1000
# 281/281 - 3s - loss: 0.0626 - snn_regressor_6_f38140e0_regression_loss: 0.0161 - snn_regressor_6_f38140e0_classification_loss: 0.0929 - snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0161 - val_loss: 0.0759 - val_snn_regressor_6_f38140e0_regression_loss: 0.0210 - val_snn_regressor_6_f38140e0_classification_loss: 0.1097 - val_snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0210 - 3s/epoch - 12ms/step
# Epoch 50/1000
# 281/281 - 3s - loss: 0.0581 - snn_regressor_6_f38140e0_regression_loss: 0.0146 - snn_regressor_6_f38140e0_classification_loss: 0.0871 - snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0146 - val_loss: 0.0572 - val_snn_regressor_6_f38140e0_regression_loss: 0.0101 - val_snn_regressor_6_f38140e0_classification_loss: 0.0941 - val_snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0101 - 3s/epoch - 12ms/step
# Epoch 51/1000
# 281/281 - 3s - loss: 0.0588 - snn_regressor_6_f38140e0_regression_loss: 0.0148 - snn_regressor_6_f38140e0_classification_loss: 0.0881 - snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0148 - val_loss: 0.0598 - val_snn_regressor_6_f38140e0_regression_loss: 0.0114 - val_snn_regressor_6_f38140e0_classification_loss: 0.0967 - val_snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0114 - 3s/epoch - 12ms/step
# Epoch 52/1000
# 281/281 - 3s - loss: 0.0554 - snn_regressor_6_f38140e0_regression_loss: 0.0135 - snn_regressor_6_f38140e0_classification_loss: 0.0838 - snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0135 - val_loss: 0.0552 - val_snn_regressor_6_f38140e0_regression_loss: 0.0104 - val_snn_regressor_6_f38140e0_classification_loss: 0.0894 - val_snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0104 - 3s/epoch - 12ms/step
# Epoch 53/1000
# 281/281 - 3s - loss: 0.0546 - snn_regressor_6_f38140e0_regression_loss: 0.0127 - snn_regressor_6_f38140e0_classification_loss: 0.0838 - snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0127 - val_loss: 0.0621 - val_snn_regressor_6_f38140e0_regression_loss: 0.0119 - val_snn_regressor_6_f38140e0_classification_loss: 0.1004 - val_snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0119 - 3s/epoch - 12ms/step
# Epoch 54/1000
# 281/281 - 3s - loss: 0.0590 - snn_regressor_6_f38140e0_regression_loss: 0.0143 - snn_regressor_6_f38140e0_classification_loss: 0.0894 - snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0143 - val_loss: 0.0541 - val_snn_regressor_6_f38140e0_regression_loss: 0.0091 - val_snn_regressor_6_f38140e0_classification_loss: 0.0901 - val_snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0091 - 3s/epoch - 12ms/step
# Epoch 55/1000
# 281/281 - 3s - loss: 0.0555 - snn_regressor_6_f38140e0_regression_loss: 0.0123 - snn_regressor_6_f38140e0_classification_loss: 0.0864 - snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0123 - val_loss: 0.0618 - val_snn_regressor_6_f38140e0_regression_loss: 0.0161 - val_snn_regressor_6_f38140e0_classification_loss: 0.0915 - val_snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0161 - 3s/epoch - 12ms/step
# Epoch 56/1000
# 281/281 - 3s - loss: 0.0573 - snn_regressor_6_f38140e0_regression_loss: 0.0132 - snn_regressor_6_f38140e0_classification_loss: 0.0882 - snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0132 - val_loss: 0.0628 - val_snn_regressor_6_f38140e0_regression_loss: 0.0134 - val_snn_regressor_6_f38140e0_classification_loss: 0.0989 - val_snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0134 - 3s/epoch - 12ms/step
# Epoch 57/1000
# 281/281 - 3s - loss: 0.0554 - snn_regressor_6_f38140e0_regression_loss: 0.0133 - snn_regressor_6_f38140e0_classification_loss: 0.0843 - snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0133 - val_loss: 0.0593 - val_snn_regressor_6_f38140e0_regression_loss: 0.0112 - val_snn_regressor_6_f38140e0_classification_loss: 0.0962 - val_snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0112 - 3s/epoch - 12ms/step
# Epoch 58/1000
# 281/281 - 3s - loss: 0.0541 - snn_regressor_6_f38140e0_regression_loss: 0.0120 - snn_regressor_6_f38140e0_classification_loss: 0.0842 - snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0120 - val_loss: 0.0564 - val_snn_regressor_6_f38140e0_regression_loss: 0.0107 - val_snn_regressor_6_f38140e0_classification_loss: 0.0915 - val_snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0107 - 3s/epoch - 12ms/step
# Epoch 59/1000
# 281/281 - 3s - loss: 0.0546 - snn_regressor_6_f38140e0_regression_loss: 0.0120 - snn_regressor_6_f38140e0_classification_loss: 0.0852 - snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0120 - val_loss: 0.0641 - val_snn_regressor_6_f38140e0_regression_loss: 0.0140 - val_snn_regressor_6_f38140e0_classification_loss: 0.1002 - val_snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0140 - 3s/epoch - 12ms/step
# Epoch 60/1000
# 281/281 - 3s - loss: 0.0553 - snn_regressor_6_f38140e0_regression_loss: 0.0120 - snn_regressor_6_f38140e0_classification_loss: 0.0865 - snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0120 - val_loss: 0.0541 - val_snn_regressor_6_f38140e0_regression_loss: 0.0062 - val_snn_regressor_6_f38140e0_classification_loss: 0.0958 - val_snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0062 - 3s/epoch - 12ms/step
# Epoch 61/1000
# 281/281 - 3s - loss: 0.0558 - snn_regressor_6_f38140e0_regression_loss: 0.0119 - snn_regressor_6_f38140e0_classification_loss: 0.0878 - snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0119 - val_loss: 0.0580 - val_snn_regressor_6_f38140e0_regression_loss: 0.0087 - val_snn_regressor_6_f38140e0_classification_loss: 0.0985 - val_snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0087 - 3s/epoch - 12ms/step
# Epoch 62/1000
# 281/281 - 3s - loss: 0.0548 - snn_regressor_6_f38140e0_regression_loss: 0.0116 - snn_regressor_6_f38140e0_classification_loss: 0.0866 - snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0116 - val_loss: 0.0559 - val_snn_regressor_6_f38140e0_regression_loss: 0.0091 - val_snn_regressor_6_f38140e0_classification_loss: 0.0935 - val_snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0091 - 3s/epoch - 12ms/step
# Epoch 63/1000
# 281/281 - 3s - loss: 0.0536 - snn_regressor_6_f38140e0_regression_loss: 0.0120 - snn_regressor_6_f38140e0_classification_loss: 0.0833 - snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0120 - val_loss: 0.0608 - val_snn_regressor_6_f38140e0_regression_loss: 0.0129 - val_snn_regressor_6_f38140e0_classification_loss: 0.0958 - val_snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0129 - 3s/epoch - 12ms/step
# Epoch 64/1000
# 281/281 - 3s - loss: 0.0517 - snn_regressor_6_f38140e0_regression_loss: 0.0107 - snn_regressor_6_f38140e0_classification_loss: 0.0822 - snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0107 - val_loss: 0.0560 - val_snn_regressor_6_f38140e0_regression_loss: 0.0109 - val_snn_regressor_6_f38140e0_classification_loss: 0.0902 - val_snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0109 - 3s/epoch - 12ms/step
# Epoch 65/1000
# 281/281 - 3s - loss: 0.0514 - snn_regressor_6_f38140e0_regression_loss: 0.0101 - snn_regressor_6_f38140e0_classification_loss: 0.0825 - snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0101 - val_loss: 0.0563 - val_snn_regressor_6_f38140e0_regression_loss: 0.0105 - val_snn_regressor_6_f38140e0_classification_loss: 0.0916 - val_snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0105 - 3s/epoch - 12ms/step
# Epoch 66/1000
# 281/281 - 3s - loss: 0.0556 - snn_regressor_6_f38140e0_regression_loss: 0.0116 - snn_regressor_6_f38140e0_classification_loss: 0.0879 - snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0116 - val_loss: 0.0552 - val_snn_regressor_6_f38140e0_regression_loss: 0.0081 - val_snn_regressor_6_f38140e0_classification_loss: 0.0943 - val_snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0081 - 3s/epoch - 12ms/step
# Epoch 67/1000
# 281/281 - 3s - loss: 0.0560 - snn_regressor_6_f38140e0_regression_loss: 0.0120 - snn_regressor_6_f38140e0_classification_loss: 0.0880 - snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0120 - val_loss: 0.0654 - val_snn_regressor_6_f38140e0_regression_loss: 0.0145 - val_snn_regressor_6_f38140e0_classification_loss: 0.1017 - val_snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0145 - 3s/epoch - 12ms/step
# Epoch 68/1000
# 281/281 - 3s - loss: 0.0521 - snn_regressor_6_f38140e0_regression_loss: 0.0102 - snn_regressor_6_f38140e0_classification_loss: 0.0838 - snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0102 - val_loss: 0.0563 - val_snn_regressor_6_f38140e0_regression_loss: 0.0087 - val_snn_regressor_6_f38140e0_classification_loss: 0.0951 - val_snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0087 - 3s/epoch - 12ms/step
# Epoch 69/1000
# 281/281 - 3s - loss: 0.0514 - snn_regressor_6_f38140e0_regression_loss: 0.0097 - snn_regressor_6_f38140e0_classification_loss: 0.0834 - snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0097 - val_loss: 0.0578 - val_snn_regressor_6_f38140e0_regression_loss: 0.0138 - val_snn_regressor_6_f38140e0_classification_loss: 0.0879 - val_snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0138 - 3s/epoch - 12ms/step
# Epoch 70/1000
# 281/281 - 3s - loss: 0.0511 - snn_regressor_6_f38140e0_regression_loss: 0.0100 - snn_regressor_6_f38140e0_classification_loss: 0.0823 - snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0100 - val_loss: 0.0533 - val_snn_regressor_6_f38140e0_regression_loss: 0.0087 - val_snn_regressor_6_f38140e0_classification_loss: 0.0893 - val_snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0087 - 3s/epoch - 12ms/step
# Epoch 71/1000
# 281/281 - 3s - loss: 0.0552 - snn_regressor_6_f38140e0_regression_loss: 0.0114 - snn_regressor_6_f38140e0_classification_loss: 0.0876 - snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0114 - val_loss: 0.0562 - val_snn_regressor_6_f38140e0_regression_loss: 0.0100 - val_snn_regressor_6_f38140e0_classification_loss: 0.0924 - val_snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0100 - 3s/epoch - 12ms/step
# Epoch 72/1000
# 281/281 - 3s - loss: 0.0526 - snn_regressor_6_f38140e0_regression_loss: 0.0100 - snn_regressor_6_f38140e0_classification_loss: 0.0854 - snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0100 - val_loss: 0.0543 - val_snn_regressor_6_f38140e0_regression_loss: 0.0084 - val_snn_regressor_6_f38140e0_classification_loss: 0.0918 - val_snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0084 - 3s/epoch - 12ms/step
# Epoch 73/1000
# 281/281 - 3s - loss: 0.0541 - snn_regressor_6_f38140e0_regression_loss: 0.0105 - snn_regressor_6_f38140e0_classification_loss: 0.0873 - snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0105 - val_loss: 0.0629 - val_snn_regressor_6_f38140e0_regression_loss: 0.0128 - val_snn_regressor_6_f38140e0_classification_loss: 0.1001 - val_snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0128 - 3s/epoch - 12ms/step
# Epoch 74/1000
# 281/281 - 3s - loss: 0.0536 - snn_regressor_6_f38140e0_regression_loss: 0.0100 - snn_regressor_6_f38140e0_classification_loss: 0.0872 - snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0100 - val_loss: 0.0579 - val_snn_regressor_6_f38140e0_regression_loss: 0.0106 - val_snn_regressor_6_f38140e0_classification_loss: 0.0946 - val_snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0106 - 3s/epoch - 12ms/step
# Epoch 75/1000
# Restoring model weights from the end of the best epoch: 60.
# 281/281 - 3s - loss: 0.0510 - snn_regressor_6_f38140e0_regression_loss: 0.0095 - snn_regressor_6_f38140e0_classification_loss: 0.0830 - snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0095 - val_loss: 0.0540 - val_snn_regressor_6_f38140e0_regression_loss: 0.0084 - val_snn_regressor_6_f38140e0_classification_loss: 0.0912 - val_snn_regressor_6_f38140e0_regression_mean_absolute_error: 0.0084 - 3s/epoch - 12ms/step
# Epoch 75: early stopping
# SNNRegressor(ensemble_size=6, minibatch_size=128, n_layers=6, verbose=True)

# %%
pred = snn.predict(X)

# %%
print('MSE: %.4f' % mean_squared_error(y, pred))
print('MAE: %.4f' % mean_absolute_error(y, pred))
print('R^2: %.4f' % r2_score(y, pred))
# Out:
# MSE: 213.6601
# MAE: 2.7324
# R^2: 0.9997
